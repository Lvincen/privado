# %%
import pickle
import numpy as np

# %%
path = 'C:/Users/LENOVO/freegsnke/machine_configs/MAST-U/MAST-U_like_limiter.pickle'

with open(path, 'rb') as f:
    limiter_data = pickle.load(f)

print(type (limiter_data))
# Out:
# <class 'list'>

# %%
print(len(limiter_data))
# Out:
# 47

# %%
for i, item in enumerate(limiter_data[:47]):  # Muestra los primeros 5 elementos
    print(f"\nElemento {i}:")
    print(f"Tipo: {type(item)}")
    print(item)
# Out:
# Elemento 0:
# Tipo: <class 'dict'>
# {'R': 0.538011, 'Z': 1.49874}
#
# Elemento 1:
# Tipo: <class 'dict'>
# {'R': 0.332797, 'Z': 1.29709}
#
# Elemento 2:
# Tipo: <class 'dict'>
# {'R': 0.332797, 'Z': 1.094}
#
# Elemento 3:
# Tipo: <class 'dict'>
# {'R': 0.334796, 'Z': 1.094}
#
# Elemento 4:
# Tipo: <class 'dict'>
# {'R': 0.303115, 'Z': 0.8475}
#
# Elemento 5:
# Tipo: <class 'dict'>
# {'R': 0.305114, 'Z': 0.8475}
#
# Elemento 6:
# Tipo: <class 'dict'>
# {'R': 0.269136, 'Z': 0.565}
#
# Elemento 7:
# Tipo: <class 'dict'>
# {'R': 0.271135, 'Z': 0.565}
#
# Elemento 8:
# Tipo: <class 'dict'>
# {'R': 0.260841, 'Z': 0.495258}
#
# Elemento 9:
# Tipo: <class 'dict'>
# {'R': 0.260841, 'Z': -0.507258}
#
# Elemento 10:
# Tipo: <class 'dict'>
# {'R': 0.271135, 'Z': -0.577}
#
# Elemento 11:
# Tipo: <class 'dict'>
# {'R': 0.269136, 'Z': -0.577}
#
# Elemento 12:
# Tipo: <class 'dict'>
# {'R': 0.305114, 'Z': -0.8595}
#
# Elemento 13:
# Tipo: <class 'dict'>
# {'R': 0.303115, 'Z': -0.8595}
#
# ...

# %%
path = 'C:/Users/LENOVO/freegsnke/machine_configs/MAST-U/MAST-U_like_active_coils.pickle'

with open(path, 'rb') as f:
    coils_data = pickle.load(f)

print(type (coils_data))
print(list(coils_data.keys()))
# Out:
# <class 'dict'>
# ['Solenoid', 'PX', 'D1', 'D2', 'D3', 'Dp', 'D5', 'D6', 'D7', 'P4', 'P5', 'P6']

# %%
print(len(coils_data))
# Out:
# 12

# %%
valor = coils_data['Solenoid']  # Reemplaza 'Solenoid' por cualquier otra clave
print(valor) #datos individuales
# Out:
# {'R': [0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0.19475, 0
# ...

# %%
for key in coils_data: #Datos de todas las bobinas activas
    print(f"\n🔹 Llave: {key}")
    print(f"📦 Valor asociado: {coils_data[key]}")
# Out:
# 🔹 Llave: Solenoid
# ...

# %%
path = 'C:/Users/LENOVO/freegsnke/machine_configs/MAST-U/MAST-U_like_passive_coils.pickle'

with open(path, 'rb') as f:
    pcoils_data = pickle.load(f)

print(type (pcoils_data))
# Out:
# <class 'list'>

# %%
print(len(pcoils_data))
# Out:
# 138

# %%
for i, item in enumerate(pcoils_data[:138]):  # Muestra los primeros 5 elementos
    print(f"\nElemento {i}:")
    print(f"Tipo: {type(item)}")
    print(item)
# Out:
# Elemento 0:
# Tipo: <class 'dict'>
# {'R': [np.float64(1.9995000269263983), np.float64(1.9995000269263983), np.float64(2.0195000264793634), np.float64(2.0195000264793634)], 'Z': [np.float64(-2.1755000054836273), np.float64(-1.6317500174045563), np.float64(-1.6317500174045563), np.float64(-2.1755000054836273)], 'resistivity': np.float32(7.1e-07), 'efitGroup': 'VS6L', 'element': 'vessel', 'name': 'vessel_1', 'current_multiplier': np.float32(0.36687815)}
#
# Elemento 1:
# Tipo: <class 'dict'>
# {'R': [np.float64(1.9995000269263983), np.float64(1.9995000269263983), np.float64(2.0195000264793634), np.float64(2.0195000264793634)], 'Z': [np.float64(-1.6317499577999115), np.float64(-1.0879999697208405), np.float64(-1.0879999697208405), np.float64(-1.6317499577999115)], 'resistivity': np.float32(7.1e-07), 'efitGroup': 'VS6L', 'element': 'vessel', 'name': 'vessel_2', 'current_multiplier': np.float32(0.36687815)}
#
# Elemento 2:
# Tipo: <class 'dict'>
# ...

# %%
path = 'C:/Users/LENOVO/freegsnke/machine_configs/MAST-U/MAST-U_like_wall.pickle'

with open(path, 'rb') as f:
    wall_data = pickle.load(f)

print(type (wall_data))
# Out:
# <class 'list'>

# %%
print(len(wall_data))
# Out:
# 91

# %%
for i, item in enumerate(wall_data[:91]):  # Muestra los elementos
    print(f"\nElemento {i}:")
    print(f"Tipo: {type(item)}")
    print(item)
# Out:
# Elemento 0:
# Tipo: <class 'dict'>
# {'R': 1.56442, 'Z': 1.56424}
#
# Elemento 1:
# Tipo: <class 'dict'>
# {'R': 1.73298, 'Z': 1.67902}
#
# Elemento 2:
# Tipo: <class 'dict'>
# {'R': 1.34848, 'Z': 2.06041}
#
# Elemento 3:
# Tipo: <class 'dict'>
# {'R': 1.0882, 'Z': 2.05946}
#
# Elemento 4:
# Tipo: <class 'dict'>
# {'R': 0.902253, 'Z': 1.87565}
#
# Elemento 5:
# Tipo: <class 'dict'>
# {'R': 0.903669, 'Z': 1.87424}
#
# Elemento 6:
# Tipo: <class 'dict'>
# {'R': 0.533866, 'Z': 1.50286}
#
# Elemento 7:
# Tipo: <class 'dict'>
# {'R': 0.538011, 'Z': 1.49874}
#
# Elemento 8:
# Tipo: <class 'dict'>
# {'R': 0.332797, 'Z': 1.29709}
#
# Elemento 9:
# Tipo: <class 'dict'>
# {'R': 0.332797, 'Z': 1.094}
#
# Elemento 10:
# Tipo: <class 'dict'>
# {'R': 0.334796, 'Z': 1.094}
#
# Elemento 11:
# Tipo: <class 'dict'>
# {'R': 0.303115, 'Z': 0.8475}
#
# Elemento 12:
# Tipo: <class 'dict'>
# {'R': 0.305114, 'Z': 0.8475}
#
# Elemento 13:
# Tipo: <class 'dict'>
# {'R': 0.269136, 'Z': 0.565}
#
# Elemento 14:
# ...

# %%
path = 'C:/Users/LENOVO/freegsnke/machine_configs/MAST-U/MAST-U_like_magnetic_probes.pickle'

with open(path, 'rb') as f:
    magnetic_probes_data = pickle.load(f)

print(type (magnetic_probes_data))
print(list(magnetic_probes_data.keys()))
# Out:
# <class 'dict'>
# ['flux_loops', 'pickups']

# %%
print(len(magnetic_probes_data))
# Out:
# 2

# %%
for key in magnetic_probes_data: #Datos de todas las bobinas activas
    print(f"\n🔹 Llave: {key}")
    print(f"📦 Valor asociado: {magnetic_probes_data[key]}")
# Out:
# 🔹 Llave: flux_loops
# ...
