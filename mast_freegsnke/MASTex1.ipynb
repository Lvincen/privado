# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt
from freegsnke import build_machine
from freegsnke.jtor_update import ConstrainPaxisIp
from freegsnke import GSstaticsolver
from freegsnke import equilibrium_update

# %%
tokamak = build_machine.tokamak(
    active_coils_path=f"C:/Users/LENOVO/Desktop/Datos tesis/freegsnke/machine_configs/MAST-U/MAST-U_like_active_coils.pickle",
    passive_coils_path=f"C:/Users/LENOVO/Desktop/Datos tesis/freegsnke/machine_configs/MAST-U/MAST-U_like_passive_coils.pickle",
    limiter_path=f"C:/Users/LENOVO/Desktop/Datos tesis/freegsnke/machine_configs/MAST-U/MAST-U_like_limiter.pickle",
    wall_path=f"C:/Users/LENOVO/Desktop/Datos tesis/freegsnke/machine_configs/MAST-U/MAST-U_like_wall.pickle",
)
# Out:
# Active coils --> built from pickle file.
# Passive structures --> built from pickle file.
# Limiter --> built from pickle file.
# Wall --> built from pickle file.
# Magnetic probes --> none provided.
# Resistance (R) and inductance (M) matrices --> built using actives (and passives if present).
# Tokamak built.

# %%
fig1, ax1 = plt.subplots(1, 1, figsize=(4, 8), dpi=80)
plt.tight_layout()

tokamak.plot(axis=ax1, show=False)
ax1.plot(tokamak.limiter.R, tokamak.limiter.Z, color='k', linewidth=1.2, linestyle="--")
ax1.plot(tokamak.wall.R, tokamak.wall.Z, color='k', linewidth=1.2, linestyle="-")

ax1.grid(alpha=0.5)
ax1.set_aspect('equal')
ax1.set_xlim(0.1, 2.15)
ax1.set_ylim(-2.25, 2.25)
ax1.set_xlabel(r'Major radius, $R$ [m]')
ax1.set_ylabel(r'Height, $Z$ [m]')
# Out:
# Text(10.027777777777777, 0.5, 'Height, $Z$ [m]')

# %%
eq = equilibrium_update.Equilibrium(
    tokamak=tokamak,      # provide tokamak object
    Rmin=0.1, Rmax=2.0,   # radial range
    Zmin=-2.2, Zmax=2.2,  # vertical range
    nx=65,                # number of grid points in the radial direction (needs to be of the form (2**n + 1) with n being an integer)
    ny=129,               # number of grid points in the vertical direction (needs to be of the form (2**n + 1) with n being an integer)
    # psi=plasma_psi
)

# %%
profiles = ConstrainPaxisIp(
    eq=eq,        # equilibrium object
    paxis=8e3,    # profile object
    Ip=6e5,       # plasma current
    fvac=0.5,     # fvac = rB_{tor}
    alpha_m=1.8,  # profile function parameter
    alpha_n=1.2   # profile function parameter
)

# %%
GSStaticSolver = GSstaticsolver.NKGSsolver(eq)

# %%
Rx = 0.6      # X-point radius
Zx = 1.1      # X-point height
Ra = .85
Rout = 1.4    # outboard midplane radius
Rin = 0.34    # inboard midplane radius

# set desired null_points locations
# this can include X-point and O-point locations
null_points = [[Rx, Rx], [Zx, -Zx]]

# set desired isoflux constraints with format 
# isoflux_set = [isoflux_0, isoflux_1 ... ] 
# with each isoflux_i = [R_coords, Z_coords]
isoflux_set = np.array([[[Rx, Rx, Rin, Rout, 1.3, 1.3, .8,.8], [Zx, -Zx, 0.,0., 2.1, -2.1,1.62,-1.62]]])
           
# instantiate the freegsnke constrain object
from freegsnke.inverse import Inverse_optimizer
constrain = Inverse_optimizer(null_points=null_points,
                              isoflux_set=isoflux_set)

# %%
eq.tokamak.set_coil_current('Solenoid', 5000)
eq.tokamak['Solenoid'].control = False  # ensures the current in the Solenoid is fixed

# %%
GSStaticSolver.solve(eq=eq, 
                     profiles=profiles, 
                     constrain=constrain, 
                     target_relative_tolerance=1e-6,
                     target_relative_psit_update=1e-3,
                     verbose=True, # print output
                     l2_reg=np.array([1e-12]*10+[1e-6]), 
                     )
# Out:
# -----
# Inverse static solve starting...
# Initial guess for plasma_psi successful, residual found.
# Initial relative error = 1.02e+00
# -----
# Iteration: 0
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-5.76e+01', '2.98e+04', '1.11e+04', '1.30e+04', '-7.91e+03', '2.73e+04', '-1.35e+04', '-6.50e+03', '-3.55e+04', '4.80e+03', '-3.67e-10']
# Constraint losses = 7.38e-01
# Relative update of tokamak psi (in plasma core): 2.53e+01
# Handing off to forward solve (with updated currents).
# Relative error =  9.31e-01
# -----
# Iteration: 1
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['2.01e+03', '-7.50e+03', '-2.81e+03', '-3.41e+03', '2.30e+03', '-7.39e+03', '3.88e+03', '1.88e+03', '9.76e+03', '-2.45e+03', '-2.06e-10']
# Constraint losses = 1.70e-01
# Relative update of tokamak psi (in plasma core): 2.62e-02
# Handing off to forward solve (with updated currents).
# Relative error =  8.67e-01
# -----
# Iteration: 2
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['1.42e+03', '-5.47e+03', '-2.05e+03', '-2.48e+03', '1.68e+03', '-5.37e+03', '2.82e+03', '1.37e+03', '7.09e+03', '-1.85e+03', '-3.23e-10']
# Constraint losses = 1.23e-01
# Relative update of tokamak psi (in plasma core): 2.61e-02
# Handing off to forward solve (with updated currents).
# Relative error =  7.77e-01
# -----
# Iteration: 3
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['9.70e+02', '-3.99e+03', '-1.50e+03', '-1.81e+03', '1.22e+03', '-3.91e+03', '2.06e+03', '9.94e+02', '5.15e+03', '-1.41e+03', '-3.67e-10']
# Constraint losses = 8.82e-02
# Relative update of tokamak psi (in plasma core): 2.52e-02
# Handing off to forward solve (with updated currents).
# Relative error =  6.52e-01
# -----
# Iteration: 4
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['6.28e+02', '-2.90e+03', '-1.10e+03', '-1.33e+03', '8.95e+02', '-2.84e+03', '1.50e+03', '7.19e+02', '3.73e+03', '-1.09e+03', '-2.50e-10']
# Constraint losses = 6.33e-02
# Relative update of tokamak psi (in plasma core): 2.32e-02
# Handing off to forward solve (with updated currents).
# Relative error =  4.80e-01
# -----
# Iteration: 5
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['3.51e+02', '-2.09e+03', '-8.13e+02', '-9.87e+02', '6.57e+02', '-2.06e+03', '1.09e+03', '5.15e+02', '2.68e+03', '-8.48e+02', '-6.75e-11']
# Constraint losses = 4.53e-02
# Relative update of tokamak psi (in plasma core): 1.96e-02
# Handing off to forward solve (with updated currents).
# Relative error =  2.48e-01
# -----
# Iteration: 6
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['8.95e+01', '-1.46e+03', '-6.02e+02', '-7.45e+02', '4.83e+02', '-1.48e+03', '7.77e+02', '3.58e+02', '1.88e+03', '-6.78e+02', '-1.09e-10']
# Constraint losses = 3.22e-02
# Relative update of tokamak psi (in plasma core): 1.43e-02
# Handing off to forward solve (with updated currents).
# Relative error =  3.66e-02
# -----
# Iteration: 7
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-3.04e+02', '-6.33e+02', '-3.50e+02', '-4.77e+02', '2.75e+02', '-7.56e+02', '3.95e+02', '1.60e+02', '8.84e+02', '-4.44e+02', '7.93e-14']
# Constraint losses = 1.83e-02
# Relative update of tokamak psi (in plasma core): 9.07e-03
# Handing off to forward solve (with updated currents).
# Relative error =  5.49e-05
# -----
# Iteration: 8
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-3.01e+02', '1.02e+02', '-2.87e+01', '-5.33e+01', '7.63e+00', '4.84e+01', '-1.15e+01', '-2.18e+01', '-1.15e+02', '-1.70e+02', '6.67e-13']
# Constraint losses = 4.19e-02
# Relative update of tokamak psi (in plasma core): 1.88e-02
# Handing off to forward solve (with updated currents).
# Relative error =  2.08e-05
# -----
# Iteration: 9
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-9.83e+01', '1.85e+02', '3.79e+01', '-3.53e+00', '-1.75e+01', '6.61e+01', '-6.91e+01', '-4.49e+01', '-1.41e+02', '1.92e+02', '5.46e-11']
# Constraint losses = 6.93e-03
# Relative update of tokamak psi (in plasma core): 6.83e-03
# Handing off to forward solve (with updated currents).
# Relative error =  5.46e-05
# -----
# Iteration: 10
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-1.90e+02', '1.14e+01', '-3.92e+01', '-4.67e+01', '1.40e+01', '7.64e+00', '2.14e+01', '3.47e+00', '-2.33e+01', '-1.87e+02', '2.70e-10']
# Constraint losses = 1.85e-02
# Relative update of tokamak psi (in plasma core): 1.41e-02
# Handing off to forward solve (with updated currents).
# Relative error =  9.56e-05
# -----
# Iteration: 11
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['2.21e+02', '-5.95e+01', '2.91e+01', '4.44e+01', '-8.91e+00', '-3.01e+01', '-2.76e+00', '9.24e+00', '6.87e+01', '1.64e+02', '2.15e-09']
# Constraint losses = 2.21e-02
# Relative update of tokamak psi (in plasma core): 1.25e-02
# Handing off to forward solve (with updated currents).
# Relative error =  3.66e-05
# -----
# Iteration: 12
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-1.66e+02', '3.57e+01', '-2.50e+01', '-3.53e+01', '8.12e+00', '1.84e+01', '6.29e+00', '-4.39e+00', '-4.33e+01', '-1.32e+02', '2.83e-08']
# Constraint losses = 1.83e-02
# Relative update of tokamak psi (in plasma core): 1.12e-02
# Handing off to forward solve (with updated currents).
# Relative error =  5.57e-05
# -----
# Iteration: 13
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['1.69e+02', '-3.41e+01', '2.51e+01', '3.44e+01', '-8.10e+00', '-1.90e+01', '-6.07e+00', '4.80e+00', '4.52e+01', '1.40e+02', '4.12e-07']
# Constraint losses = 1.36e-02
# Relative update of tokamak psi (in plasma core): 1.05e-02
# Handing off to forward solve (with updated currents).
# Relative error =  5.55e-05
# -----
# Iteration: 14
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-1.52e+02', '3.07e+01', '-2.30e+01', '-3.18e+01', '7.50e+00', '1.64e+01', '6.07e+00', '-3.87e+00', '-3.92e+01', '-1.24e+02', '3.19e-06']
# Constraint losses = 2.01e-02
# Relative update of tokamak psi (in plasma core): 1.05e-02
# Handing off to forward solve (with updated currents).
# Relative error =  5.91e-05
# -----
# Iteration: 15
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['1.41e+02', '-2.44e+01', '2.21e+01', '2.91e+01', '-7.28e+00', '-1.43e+01', '-6.57e+00', '3.18e+00', '3.52e+01', '1.22e+02', '6.42e-05']
# Constraint losses = 9.87e-03
# Relative update of tokamak psi (in plasma core): 9.11e-03
# Handing off to forward solve (with updated currents).
# Relative error =  2.77e-05
# -----
# Iteration: 16
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-1.34e+02', '2.66e+01', '-2.04e+01', '-2.80e+01', '6.65e+00', '1.44e+01', '5.45e+00', '-3.38e+00', '-3.45e+01', '-1.10e+02', '-1.82e-06']
# Constraint losses = 1.92e-02
# Relative update of tokamak psi (in plasma core): 9.24e-03
# Handing off to forward solve (with updated currents).
# Relative error =  5.36e-05
# -----
# Iteration: 17
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['1.28e+02', '-2.17e+01', '2.02e+01', '2.64e+01', '-6.64e+00', '-1.29e+01', '-6.04e+00', '2.85e+00', '3.17e+01', '1.11e+02', '-2.53e-05']
# Constraint losses = 7.40e-03
# Relative update of tokamak psi (in plasma core): 8.40e-03
# Handing off to forward solve (with updated currents).
# Relative error =  6.55e-05
# -----
# Iteration: 18
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-1.10e+02', '2.00e+01', '-1.71e+01', '-2.29e+01', '5.63e+00', '1.12e+01', '5.03e+00', '-2.47e+00', '-2.73e+01', '-9.28e+01', '-9.78e-05']
# Constraint losses = 1.91e-02
# Relative update of tokamak psi (in plasma core): 7.70e-03
# Handing off to forward solve (with updated currents).
# Relative error =  3.83e-06
# -----
# Iteration: 19
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['5.47e+01', '-6.31e+00', '9.26e+00', '1.12e+01', '-3.13e+00', '-4.49e+00', '-3.47e+00', '7.27e-01', '1.19e+01', '5.09e+01', '1.80e-07']
# Constraint losses = 3.25e-03
# Relative update of tokamak psi (in plasma core): 3.79e-03
# Handing off to forward solve (with updated currents).
# Relative error =  1.58e-05
# -----
# Iteration: 20
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-9.18e+01', '1.89e+01', '-1.39e+01', '-1.92e+01', '4.49e+00', '1.01e+01', '3.54e+00', '-2.44e+00', '-2.40e+01', '-7.51e+01', '2.31e-05']
# Constraint losses = 8.38e-03
# Relative update of tokamak psi (in plasma core): 6.12e-03
# Handing off to forward solve (with updated currents).
# Relative error =  5.85e-06
# -----
# Iteration: 21
# Using full Jacobian (of constraints wrt coil currents) to optimsise currents.
#  - calculating derivatives for coil 1/11
#  - calculating derivatives for coil 2/11
#  - calculating derivatives for coil 3/11
#  - calculating derivatives for coil 4/11
#  - calculating derivatives for coil 5/11
#  - calculating derivatives for coil 6/11
#  - calculating derivatives for coil 7/11
#  - calculating derivatives for coil 8/11
#  - calculating derivatives for coil 9/11
#  - calculating derivatives for coil 10/11
#  - calculating derivatives for coil 11/11
# Change in coil currents (being controlled): ['9.44e-01', '9.52e-01', '7.09e-01', '6.73e-01', '2.54e+00', '4.10e+00', '4.17e+00', '5.16e+00', '8.53e+00', '2.05e+01', '2.75e-04']
# Constraint losses = 1.52e-03
# Relative update of tokamak psi (in plasma core): 1.96e-03
# Handing off to forward solve (with updated currents).
# Relative error =  1.59e-05
# -----
# Iteration: 22
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['7.34e+01', '-1.01e+01', '1.20e+01', '1.49e+01', '-6.11e+00', '-9.40e+00', '-7.70e+00', '-2.66e+00', '1.07e+01', '5.45e+01', '3.59e-05']
# Constraint losses = 3.49e-03
# Relative update of tokamak psi (in plasma core): 3.74e-03
# Handing off to forward solve (with updated currents).
# Relative error =  2.39e-05
# -----
# Iteration: 23
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-5.26e+01', '9.52e+00', '-8.31e+00', '-1.11e+01', '2.50e+00', '5.01e+00', '2.13e+00', '-1.56e+00', '-1.36e+01', '-4.63e+01', '6.39e-06']
# Constraint losses = 8.12e-03
# Relative update of tokamak psi (in plasma core): 3.75e-03
# Handing off to forward solve (with updated currents).
# Relative error =  1.06e-05
# -----
# Iteration: 24
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['5.35e+01', '-1.35e+01', '7.27e+00', '1.08e+01', '-2.67e+00', '-7.40e+00', '-1.66e+00', '1.28e+00', '1.46e+01', '3.76e+01', '1.08e-05']
# Constraint losses = 2.76e-03
# Relative update of tokamak psi (in plasma core): 2.98e-03
# Handing off to forward solve (with updated currents).
# Relative error =  2.22e-05
# -----
# Iteration: 25
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-3.74e+01', '7.53e+00', '-5.62e+00', '-7.71e+00', '1.77e+00', '4.07e+00', '1.32e+00', '-1.12e+00', '-1.01e+01', '-3.12e+01', '4.48e-05']
# Constraint losses = 6.15e-03
# Relative update of tokamak psi (in plasma core): 2.54e-03
# Handing off to forward solve (with updated currents).
# Relative error =  4.11e-06
# -----
# Iteration: 26
# Using full Jacobian (of constraints wrt coil currents) to optimsise currents.
#  - calculating derivatives for coil 1/11
#  - calculating derivatives for coil 2/11
#  - calculating derivatives for coil 3/11
#  - calculating derivatives for coil 4/11
#  - calculating derivatives for coil 5/11
#  - calculating derivatives for coil 6/11
#  - calculating derivatives for coil 7/11
#  - calculating derivatives for coil 8/11
#  - calculating derivatives for coil 9/11
#  - calculating derivatives for coil 10/11
#  - calculating derivatives for coil 11/11
# Change in coil currents (being controlled): ['1.11e-01', '1.08e-01', '7.23e-02', '6.05e-02', '2.73e-01', '4.57e-01', '4.62e-01', '5.69e-01', '9.36e-01', '2.32e+00', '1.52e-04']
# Constraint losses = 2.05e-04
# Relative update of tokamak psi (in plasma core): 2.25e-04
# Handing off to forward solve (with updated currents).
# Relative error =  5.30e-07
# -----
# Inverse static solve SUCCESS. Tolerance 5.30e-07 (vs. requested 1e-06) reached in 27/100 iterations.

# %%
fig1, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(12, 8), dpi=80)

ax1.grid(zorder=0, alpha=0.75)
ax1.set_aspect('equal')
eq.tokamak.plot(axis=ax1,show=False)                                                          # plots the active coils and passive structures
ax1.fill(tokamak.wall.R, tokamak.wall.Z, color='k', linewidth=1.2, facecolor='w', zorder=0)   # plots the limiter
ax1.set_xlim(0.1, 2.15)
ax1.set_ylim(-2.25, 2.25)

ax2.grid(zorder=0, alpha=0.75)
ax2.set_aspect('equal')
eq.tokamak.plot(axis=ax2,show=False)                                                          # plots the active coils and passive structures
ax2.fill(tokamak.wall.R, tokamak.wall.Z, color='k', linewidth=1.2, facecolor='w', zorder=0)   # plots the limiter
eq.plot(axis=ax2,show=False)                                                                  # plots the equilibrium
ax2.set_xlim(0.1, 2.15)
ax2.set_ylim(-2.25, 2.25)


ax3.grid(zorder=0, alpha=0.75)
ax3.set_aspect('equal')
eq.tokamak.plot(axis=ax3,show=False)                                                          # plots the active coils and passive structures
ax3.fill(tokamak.wall.R, tokamak.wall.Z, color='k', linewidth=1.2, facecolor='w', zorder=0)   # plots the limiter
eq.plot(axis=ax3,show=False)                                                                  # plots the equilibrium
constrain.plot(axis=ax3, show=True)                             
ax3.set_xlim(0.1, 2.15)
ax3.set_ylim(-2.25, 2.25)

plt.tight_layout()

# %%
inverse_current_values = eq.tokamak.getCurrents()

# save coil currents to file
with open('simple_diverted_currents_PaxisIp.pk', 'wb') as f:
    pickle.dump(obj=inverse_current_values, file=f)

# %%
with open('simple_diverted_currents_PaxisIp.pk', 'rb') as g:
    data=pickle.load(g)
print(type(data))
print(list(data.keys()))
# Out:
# <class 'dict'>
# ['Solenoid', 'PX', 'D1', 'D2', 'D3', 'Dp', 'D5', 'D6', 'D7', 'P4', 'P5', 'P6', 'vessel_1', 'vessel_2', 'vessel_3', 'vessel_4', 'vessel_5', 'vessel_6', 'vessel_7', 'vessel_8', 'vessel_9', 'vessel_10', 'vessel_11', 'vessel_12', 'vessel_13', 'vessel_14', 'vessel_15', 'vessel_16', 'vessel_17', 'vessel_18', 'vessel_19', 'vessel_20', 'vessel_21', 'vessel_22', 'centrecolumn_1', 'centrecolumn_2', 'centrecolumn_3', 'centrecolumn_4', 'centrecolumn_5', 'centrecolumn_6', 'centrecolumn_7', 'centrecolumn_8', 'centrecolumn_9', 'centrecolumn_10', 'colosseum_upper_1', 'colosseum_upper_2', 'colosseum_upper_3', 'colosseum_lower_1', 'colosseum_lower_2', 'colosseum_lower_3', 'colosseum_outer_upper_1', 'colosseum_outer_upper_2', 'colosseum_outer_lower_1', 'colosseum_outer_lower_2', 'ring_plate_minor_upper_1', 'ring_plate_minor_upper_2', 'ring_plate_minor_lower_1', 'ring_plate_minor_lower_2', 'ring_plate_major_upper_1', 'ring_plate_major_lower_1', 'psp_upper_1', 'psp_lower_1', 'gas_baffle_upper_1', 'gas_baffle_upper_2', 'gas_baffle_upper_3', 'gas_baffle_lower_1', 'gas_baffle_lower_2', 'gas_baffle_lower_3', 'd1_case_upper_0', 'd1_case_upper_1', 'd1_case_upper_2', 'd1_case_upper_3', 'd1_case_lower_0', 'd1_case_lower_1', 'd1_case_lower_2', 'd1_case_lower_3', 'd2_case_upper_0', 'd2_case_upper_1', 'd2_case_upper_2', 'd2_case_upper_3', 'd2_case_lower_0', 'd2_case_lower_1', 'd2_case_lower_2', 'd2_case_lower_3', 'd3_case_upper_0', 'd3_case_upper_1', 'd3_case_upper_2', 'd3_case_upper_3', 'd3_case_lower_0', 'd3_case_lower_1', 'd3_case_lower_2', 'd3_case_lower_3', 'd5_case_upper_0', 'd5_case_upper_1', 'd5_case_upper_2', 'd5_case_upper_3', 'd5_case_lower_0', 'd5_case_lower_1', 'd5_case_lower_2', 'd5_case_lower_3', 'd6_case_upper_0', 'd6_case_upper_1', 'd6_case_upper_2', 'd6_case_upper_3', 'd6_case_lower_0', 'd6_case_lower_1', 'd6_case_lower_2', 'd6_case_lower_3', 'd7_case_upper_0', 'd7_case_upper_1', 'd7_case_upper_2', 'd7_case_upper_3', 'd7_case_lower_0', 'd7_case_lower_1', 'd7_case_lower_2', 'd7_case_lower_3', 'dp_case_upper_0', 'dp_case_upper_1', 'dp_case_upper_2', 'dp_case_upper_3', 'dp_case_lower_0', 'dp_case_lower_1', 'dp_case_lower_2', 'dp_case_lower_3', 'p4_case_upper_0', 'p4_case_upper_1', 'p4_case_upper_2', 'p4_case_upper_3', 'p4_case_lower_0', 'p4_case_lower_1', 'p4_case_lower_2', 'p4_case_lower_3', 'p5_case_upper_0', 'p5_case_upper_1', 'p5_case_upper_2', 'p5_case_upper_3', 'p5_case_lower_0', 'p5_case_lower_1', 'p5_case_lower_2', 'p5_case_lower_3', 'p6_case_upper_0', 'p6_case_upper_1', 'p6_case_upper_2', 'p6_case_upper_3', 'p6_case_upper_4', 'p6_case_lower_0', 'p6_case_lower_1', 'p6_case_lower_2', 'p6_case_lower_3', 'p6_case_lower_4']

# %%
for key in data:
    print(f"\n🔹 Llave: {key}")
    print(f"📦 Valor asociado: {data[key]}")
# Out:
# 🔹 Llave: Solenoid
# 📦 Valor asociado: 5000.0
#
# 🔹 Llave: PX
# 📦 Valor asociado: 4613.049761958626
#
# 🔹 Llave: D1
# 📦 Valor asociado: 6051.841804928801
#
# 🔹 Llave: D2
# 📦 Valor asociado: 1894.9173317832135
#
# 🔹 Llave: D3
# 📦 Valor asociado: 1663.7594766897298
#
# 🔹 Llave: Dp
# 📦 Valor asociado: -397.8437425044009
#
# 🔹 Llave: D5
# 📦 Valor asociado: 3586.7284054932893
#
# 🔹 Llave: D6
# 📦 Valor asociado: -1083.6789526602354
#
# 🔹 Llave: D7
# 📦 Valor asociado: -562.9300303560887
#
# 🔹 Llave: P4
# 📦 Valor asociado: -4564.190198138347
#
# 🔹 Llave: P5
# 📦 Valor asociado: -4048.662255491955
#
# 🔹 Llave: P6
# 📦 Valor asociado: 0.0004911931468066169
#
# 🔹 Llave: vessel_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_4
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_5
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_6
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_7
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_8
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_9
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_10
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_11
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_12
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_13
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_14
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_15
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_16
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_17
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_18
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_19
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_20
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_21
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: vessel_22
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: centrecolumn_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: centrecolumn_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: centrecolumn_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: centrecolumn_4
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: centrecolumn_5
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: centrecolumn_6
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: centrecolumn_7
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: centrecolumn_8
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: centrecolumn_9
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: centrecolumn_10
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: colosseum_upper_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: colosseum_upper_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: colosseum_upper_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: colosseum_lower_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: colosseum_lower_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: colosseum_lower_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: colosseum_outer_upper_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: colosseum_outer_upper_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: colosseum_outer_lower_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: colosseum_outer_lower_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: ring_plate_minor_upper_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: ring_plate_minor_upper_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: ring_plate_minor_lower_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: ring_plate_minor_lower_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: ring_plate_major_upper_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: ring_plate_major_lower_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: psp_upper_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: psp_lower_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: gas_baffle_upper_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: gas_baffle_upper_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: gas_baffle_upper_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: gas_baffle_lower_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: gas_baffle_lower_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: gas_baffle_lower_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d1_case_upper_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d1_case_upper_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d1_case_upper_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d1_case_upper_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d1_case_lower_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d1_case_lower_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d1_case_lower_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d1_case_lower_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d2_case_upper_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d2_case_upper_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d2_case_upper_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d2_case_upper_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d2_case_lower_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d2_case_lower_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d2_case_lower_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d2_case_lower_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d3_case_upper_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d3_case_upper_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d3_case_upper_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d3_case_upper_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d3_case_lower_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d3_case_lower_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d3_case_lower_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d3_case_lower_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d5_case_upper_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d5_case_upper_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d5_case_upper_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d5_case_upper_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d5_case_lower_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d5_case_lower_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d5_case_lower_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d5_case_lower_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d6_case_upper_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d6_case_upper_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d6_case_upper_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d6_case_upper_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d6_case_lower_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d6_case_lower_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d6_case_lower_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d6_case_lower_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d7_case_upper_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d7_case_upper_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d7_case_upper_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d7_case_upper_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d7_case_lower_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d7_case_lower_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d7_case_lower_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: d7_case_lower_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: dp_case_upper_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: dp_case_upper_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: dp_case_upper_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: dp_case_upper_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: dp_case_lower_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: dp_case_lower_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: dp_case_lower_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: dp_case_lower_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p4_case_upper_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p4_case_upper_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p4_case_upper_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p4_case_upper_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p4_case_lower_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p4_case_lower_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p4_case_lower_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p4_case_lower_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p5_case_upper_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p5_case_upper_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p5_case_upper_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p5_case_upper_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p5_case_lower_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p5_case_lower_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p5_case_lower_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p5_case_lower_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p6_case_upper_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p6_case_upper_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p6_case_upper_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p6_case_upper_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p6_case_upper_4
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p6_case_lower_0
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p6_case_lower_1
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p6_case_lower_2
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p6_case_lower_3
# 📦 Valor asociado: 0.0
#
# 🔹 Llave: p6_case_lower_4
# 📦 Valor asociado: 0.0

# %%
eq = equilibrium_update.Equilibrium(
    tokamak=tokamak,      # provide tokamak object
    Rmin=0.1, Rmax=2.0,   # radial range
    Zmin=-2.2, Zmax=2.2,  # vertical range
    nx=65,                # number of grid points in the radial direction (needs to be of the form (2**n + 1) with n being an integer)
    ny=129,               # number of grid points in the vertical direction (needs to be of the form (2**n + 1) with n being an integer)
    # psi=plasma_psi
)

# modify the total plasma current
profiles.Ip = 4e5

# modify the pressure on the magnetic axis
profiles.paxis = 6e3

# first we specify some alternative constraints
Rout = 1.4   # outboard midplane radius
Rin = 0.24   # inboard midplane radius

# locations of X-points
Rx = 0.45
Zx = 1.18
null_points = [[Rx, Rx], [Zx, -Zx]]

# isoflux constraints
isoflux_set = [[Rx, Rx, Rout, Rin, Rin, Rin, Rin, Rin, .75, .75, .85, .85, 1.3, 1.3],
           [Zx, -Zx,  0,  0,  .1, -.1, .2, -.2, 1.6, -1.6, 1.7, -1.7, 2.1, -2.1]]

# let's assume we're also seeking an equilibrium with no solenoid current
eq.tokamak.set_coil_current('Solenoid', 0)
eq.tokamak['Solenoid'].control = False # fixes the current

# pass the magnetic constraints to a new constrain object
constrain = Inverse_optimizer(null_points=null_points,
                              isoflux_set=isoflux_set)

# carry out the solve
GSStaticSolver.solve(eq=eq, 
                     profiles=profiles, 
                     constrain=constrain, 
                     target_relative_tolerance=1e-6,
                     target_relative_psit_update=1e-3,
                     verbose=True, # print output
                     l2_reg=np.array([1e-9]*10+[1e-5]), 
                     )
# Out:
# -----
# Inverse static solve starting...
# Initial guess for plasma_psi successful, residual found.
# Initial relative error = 9.72e-01
# -----
# Iteration: 0
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['7.05e+03', '7.90e+02', '2.84e+04', '3.23e+04', '-1.77e+04', '2.89e+04', '-2.57e+04', '-1.30e+04', '-4.43e+04', '1.54e+04', '-4.91e-05']
# Constraint losses = 8.86e-01
# Relative update of tokamak psi (in plasma core): 1.58e+00
# Handing off to forward solve (with updated currents).
# Relative error =  9.53e-01
# -----
# Iteration: 1
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-2.89e+03', '-1.94e+03', '-8.93e+03', '-1.01e+04', '5.62e+03', '-9.48e+03', '7.97e+03', '3.99e+03', '1.42e+04', '-3.89e+03', '-4.51e-05']
# Constraint losses = 3.03e-01
# Relative update of tokamak psi (in plasma core): 2.14e-02
# Handing off to forward solve (with updated currents).
# Relative error =  9.13e-01
# -----
# Iteration: 2
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-1.98e+03', '-1.34e+03', '-6.56e+03', '-7.23e+03', '3.98e+03', '-6.88e+03', '5.81e+03', '2.91e+03', '1.03e+04', '-2.90e+03', '-4.15e-05']
# Constraint losses = 2.15e-01
# Relative update of tokamak psi (in plasma core): 2.38e-02
# Handing off to forward solve (with updated currents).
# Relative error =  8.55e-01
# -----
# Iteration: 3
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-1.45e+03', '-9.54e+02', '-4.68e+03', '-5.15e+03', '2.83e+03', '-4.90e+03', '4.14e+03', '2.07e+03', '7.33e+03', '-2.13e+03', '-3.84e-05']
# Constraint losses = 1.52e-01
# Relative update of tokamak psi (in plasma core): 2.59e-02
# Handing off to forward solve (with updated currents).
# Relative error =  7.72e-01
# -----
# Iteration: 4
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-1.07e+03', '-6.80e+02', '-3.34e+03', '-3.67e+03', '2.02e+03', '-3.50e+03', '2.96e+03', '1.48e+03', '5.22e+03', '-1.59e+03', '-3.58e-05']
# Constraint losses = 1.06e-01
# Relative update of tokamak psi (in plasma core): 2.73e-02
# Handing off to forward solve (with updated currents).
# Relative error =  6.56e-01
# -----
# Iteration: 5
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-8.17e+02', '-4.83e+02', '-2.38e+03', '-2.61e+03', '1.43e+03', '-2.50e+03', '2.11e+03', '1.05e+03', '3.72e+03', '-1.20e+03', '-3.37e-05']
# Constraint losses = 7.43e-02
# Relative update of tokamak psi (in plasma core): 2.74e-02
# Handing off to forward solve (with updated currents).
# Relative error =  4.94e-01
# -----
# Iteration: 6
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-6.46e+02', '-3.40e+02', '-1.70e+03', '-1.85e+03', '1.01e+03', '-1.78e+03', '1.50e+03', '7.44e+02', '2.63e+03', '-9.33e+02', '-3.25e-05']
# Constraint losses = 5.17e-02
# Relative update of tokamak psi (in plasma core): 2.59e-02
# Handing off to forward solve (with updated currents).
# Relative error =  2.80e-01
# -----
# Iteration: 7
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-5.41e+02', '-2.29e+02', '-1.18e+03', '-1.27e+03', '6.94e+02', '-1.24e+03', '1.04e+03', '5.08e+02', '1.81e+03', '-7.37e+02', '-3.26e-05']
# Constraint losses = 3.54e-02
# Relative update of tokamak psi (in plasma core): 2.07e-02
# Handing off to forward solve (with updated currents).
# Relative error =  6.97e-02
# -----
# Iteration: 8
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-1.71e+02', '-5.78e+00', '1.69e+01', '-4.28e+01', '1.31e+02', '-1.43e+02', '3.36e+01', '-1.78e+01', '4.23e+01', '-1.11e+02', '-3.97e-09']
# Constraint losses = 2.42e-02
# Relative update of tokamak psi (in plasma core): 9.57e-03
# Handing off to forward solve (with updated currents).
# Relative error =  4.02e-02
# -----
# Iteration: 9
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-6.58e+01', '-9.32e+00', '1.21e+00', '-1.68e+00', '3.36e+01', '-2.58e+01', '6.56e+00', '-1.33e+01', '-3.06e+01', '-2.12e+02', '-2.72e-03']
# Constraint losses = 6.25e-02
# Relative update of tokamak psi (in plasma core): 2.19e-02
# Handing off to forward solve (with updated currents).
# Relative error =  1.54e-04
# -----
# Iteration: 10
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-1.50e+02', '-3.07e+01', '-1.58e+01', '-3.45e+01', '5.90e+01', '-5.52e+01', '2.57e+01', '-3.92e+00', '1.14e+01', '-1.95e+02', '-1.45e-04']
# Constraint losses = 2.45e-02
# Relative update of tokamak psi (in plasma core): 1.57e-02
# Handing off to forward solve (with updated currents).
# Relative error =  4.76e-04
# -----
# Iteration: 11
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-6.19e+01', '-2.05e+01', '-2.04e+01', '-4.62e+01', '2.59e+01', '-2.46e+01', '3.26e+01', '3.25e+01', '1.04e+02', '2.32e+02', '-9.57e-05']
# Constraint losses = 4.03e-02
# Relative update of tokamak psi (in plasma core): 1.86e-02
# Handing off to forward solve (with updated currents).
# Relative error =  7.53e-04
# -----
# Iteration: 12
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-4.27e+01', '-9.46e+00', '-5.55e+00', '-3.74e+00', '8.99e+00', '-1.24e+01', '-1.40e+00', '-1.25e+01', '-3.00e+01', '-1.65e+02', '-4.06e-04']
# Constraint losses = 4.80e-02
# Relative update of tokamak psi (in plasma core): 1.69e-02
# Handing off to forward solve (with updated currents).
# Relative error =  6.90e-05
# -----
# Iteration: 13
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-8.36e+01', '-2.58e+01', '-2.60e+01', '-4.80e+01', '2.37e+01', '-3.03e+01', '2.64e+01', '1.98e+01', '7.26e+01', '9.68e+01', '-1.01e-05']
# Constraint losses = 1.71e-02
# Relative update of tokamak psi (in plasma core): 9.55e-03
# Handing off to forward solve (with updated currents).
# Relative error =  1.36e-04
# -----
# Iteration: 14
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-4.44e+01', '-1.06e+01', '-8.64e+00', '-8.77e+00', '8.69e+00', '-1.23e+01', '1.36e+00', '-8.85e+00', '-1.99e+01', '-1.41e+02', '-2.91e-05']
# Constraint losses = 2.98e-02
# Relative update of tokamak psi (in plasma core): 1.33e-02
# Handing off to forward solve (with updated currents).
# Relative error =  1.04e-04
# -----
# Iteration: 15
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-5.43e+01', '-1.82e+01', '-2.26e+01', '-4.27e+01', '1.67e+01', '-1.86e+01', '2.60e+01', '2.50e+01', '7.89e+01', '1.50e+02', '-1.32e-04']
# Constraint losses = 2.11e-02
# Relative update of tokamak psi (in plasma core): 1.36e-02
# Handing off to forward solve (with updated currents).
# Relative error =  1.77e-04
# -----
# Iteration: 16
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-2.32e+01', '-4.78e+00', '-3.86e+00', '-1.43e+00', '3.43e+00', '-5.75e+00', '-2.12e+00', '-9.10e+00', '-2.38e+01', '-1.20e+02', '-3.24e-05']
# Constraint losses = 4.03e-02
# Relative update of tokamak psi (in plasma core): 1.22e-02
# Handing off to forward solve (with updated currents).
# Relative error =  3.99e-05
# -----
# Iteration: 17
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-4.70e+01', '-1.38e+01', '-1.83e+01', '-2.98e+01', '1.07e+01', '-1.55e+01', '1.45e+01', '9.62e+00', '3.46e+01', '1.62e+01', '2.47e-07']
# Constraint losses = 9.49e-03
# Relative update of tokamak psi (in plasma core): 2.45e-03
# Handing off to forward solve (with updated currents).
# Relative error =  1.07e-05
# -----
# Iteration: 18
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-4.19e+01', '-1.07e+01', '-1.48e+01', '-2.11e+01', '8.27e+00', '-1.29e+01', '8.41e+00', '1.23e+00', '8.94e+00', '-6.11e+01', '2.46e-06']
# Constraint losses = 1.01e-02
# Relative update of tokamak psi (in plasma core): 4.72e-03
# Handing off to forward solve (with updated currents).
# Relative error =  4.20e-05
# -----
# Iteration: 19
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-2.48e+01', '-7.58e+00', '-1.40e+01', '-2.53e+01', '7.88e+00', '-8.87e+00', '1.49e+01', '1.43e+01', '4.34e+01', '7.45e+01', '3.97e-06']
# Constraint losses = 1.32e-02
# Relative update of tokamak psi (in plasma core): 7.31e-03
# Handing off to forward solve (with updated currents).
# Relative error =  1.78e-05
# -----
# Iteration: 20
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-1.66e+01', '-3.23e+00', '-5.12e+00', '-5.04e+00', '2.33e+00', '-4.91e+00', '2.21e-01', '-4.57e+00', '-1.10e+01', '-7.49e+01', '7.28e-06']
# Constraint losses = 1.87e-02
# Relative update of tokamak psi (in plasma core): 6.87e-03
# Handing off to forward solve (with updated currents).
# Relative error =  4.60e-05
# -----
# Iteration: 21
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-2.09e+01', '-5.88e+00', '-1.32e+01', '-2.28e+01', '6.15e+00', '-8.23e+00', '1.24e+01', '1.12e+01', '3.47e+01', '4.94e+01', '4.75e-05']
# Constraint losses = 9.73e-03
# Relative update of tokamak psi (in plasma core): 5.20e-03
# Handing off to forward solve (with updated currents).
# Relative error =  5.06e-05
# -----
# Iteration: 22
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-1.21e+01', '-2.20e+00', '-4.75e+00', '-5.31e+00', '1.73e+00', '-4.06e+00', '8.16e-01', '-2.78e+00', '-6.25e+00', '-5.33e+01', '5.79e-06']
# Constraint losses = 1.39e-02
# Relative update of tokamak psi (in plasma core): 4.77e-03
# Handing off to forward solve (with updated currents).
# Relative error =  4.26e-05
# -----
# Iteration: 23
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-1.54e+01', '-3.81e+00', '-1.10e+01', '-1.86e+01', '4.64e+00', '-6.66e+00', '9.71e+00', '8.23e+00', '2.56e+01', '2.84e+01', '3.98e-05']
# Constraint losses = 7.59e-03
# Relative update of tokamak psi (in plasma core): 3.25e-03
# Handing off to forward solve (with updated currents).
# Relative error =  1.92e-05
# -----
# Iteration: 24
# Using simplified Green's Jacobian (of constraints wrt coil currents) to optimise the currents.
# Change in coil currents (being controlled): ['-1.21e+01', '-2.05e+00', '-6.39e+00', '-8.19e+00', '2.00e+00', '-4.78e+00', '2.31e+00', '-1.22e+00', '-1.57e+00', '-4.50e+01', '8.34e-07']
# Constraint losses = 9.20e-03
# Relative update of tokamak psi (in plasma core): 3.80e-03
# Handing off to forward solve (with updated currents).
# Relative error =  8.97e-06
# -----
# Iteration: 25
# Using full Jacobian (of constraints wrt coil currents) to optimsise currents.
#  - calculating derivatives for coil 1/11
#  - calculating derivatives for coil 2/11
#  - calculating derivatives for coil 3/11
#  - calculating derivatives for coil 4/11
#  - calculating derivatives for coil 5/11
#  - calculating derivatives for coil 6/11
#  - calculating derivatives for coil 7/11
#  - calculating derivatives for coil 8/11
#  - calculating derivatives for coil 9/11
#  - calculating derivatives for coil 10/11
#  - calculating derivatives for coil 11/11
# Change in coil currents (being controlled): ['-9.55e-01', '-1.05e-01', '-9.36e-01', '-1.51e+00', '1.44e+00', '1.44e+00', '3.10e+00', '3.39e+00', '6.77e+00', '9.86e+00', '-7.81e-05']
# Constraint losses = 5.49e-03
# Relative update of tokamak psi (in plasma core): 1.21e-03
# Handing off to forward solve (with updated currents).
# Relative error =  1.99e-06
# -----
# Iteration: 26
# Using full Jacobian (of constraints wrt coil currents) to optimsise currents.
#  - calculating derivatives for coil 1/11
#  - calculating derivatives for coil 2/11
#  - calculating derivatives for coil 3/11
#  - calculating derivatives for coil 4/11
#  - calculating derivatives for coil 5/11
#  - calculating derivatives for coil 6/11
#  - calculating derivatives for coil 7/11
#  - calculating derivatives for coil 8/11
#  - calculating derivatives for coil 9/11
#  - calculating derivatives for coil 10/11
#  - calculating derivatives for coil 11/11
# Change in coil currents (being controlled): ['-8.84e-01', '-2.42e-01', '-1.10e+00', '-1.80e+00', '5.78e-01', '-3.28e-01', '1.51e+00', '1.31e+00', '3.57e+00', '2.69e+00', '1.12e-04']
# Constraint losses = 5.44e-03
# Relative update of tokamak psi (in plasma core): 4.02e-04
# Handing off to forward solve (with updated currents).
# Relative error =  4.74e-07
# -----
# Inverse static solve SUCCESS. Tolerance 4.74e-07 (vs. requested 1e-06) reached in 27/100 iterations.

# %%
# save the currents for later use
inverse_current_values = eq.tokamak.getCurrents()

# save coil currents to file
with open('simple_limited_currents_PaxisIp.pk', 'wb') as f:
    pickle.dump(obj=inverse_current_values, file=f)

# %%
fig1, ax1 = plt.subplots(1, 1, figsize=(4, 8), dpi=80)
ax1.grid(True, which='both')
eq.plot(axis=ax1, show=False)
eq.tokamak.plot(axis=ax1, show=False)
constrain.plot(axis=ax1,show=True)
ax1.set_xlim(0.1, 2.15)
ax1.set_ylim(-2.25, 2.25)
plt.tight_layout()
